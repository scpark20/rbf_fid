# %%
import os
os.chdir('../../')

# %%
# !nvidia-smi
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# Mon Mar 31 14:22:51 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off |   00000000:19:00.0 Off |                  Off |
# | 62%   78C    P2            324W /  450W |    7315MiB /  24564MiB |     97%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA GeForce RTX 4090        Off |   00000000:68:00.0 Off |                  Off |
# | 75%   82C    P2            337W /  450W |    7333MiB /  24564MiB |     95%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1255      G   /usr/lib/xorg/Xorg                              4MiB |
# |    0   N/A  N/A     31891      C   ...cpark/anaconda3/envs/ste/bin/python       7298MiB |
# |    1   N/A  N/A      1255      G   /usr/lib/xorg/Xorg                              9MiB |
# |    1   N/A  N/A      1504      G   /usr/bin/gnome-shell                            8MiB |
# |    1   N/A  N/A     32174      C   ...cpark/anaconda3/envs/ste/bin/python       7298MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import sys
import torch
import numpy as np
import matplotlib.pyplot as plt
import torchvision.utils as vutils
import random

from main import parse_args_and_config, Diffusion
from datasets import inverse_data_transform

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

torch.backends.cudnn.deterministic = True
torch.backends.benchmark = False

###############################################################################
# 1) Notebook에서 sys.argv를 직접 설정 (argparse 흉내)
###############################################################################
sys.argv = [
    "main.py",
    "--config", "imagenet128_guided.yml",  # 사용하려는 config
    "--sample",
    "--eta", "0",
    "--dpm_solver_type", "data_prediction",
    "--dpm_solver_order", "3",
    "--skip_type", "logSNR",
    "--thresholding",
    "--ni",

    "--sample_type", "rbfsolverglq10laggrid",
    "--scale", "4.0",
    "--timesteps", "20",
    "--log_scale_min", "-2.0",
    "--log_scale_max", "3.0",
    "--scale_dir", "/data/data/rbfsolverglq10laggrid",
]

###############################################################################
# 2) 인자/설정 로드
###############################################################################
args, config = parse_args_and_config()

###############################################################################
# 3) Diffusion 객체 생성 -> 모델 로딩
###############################################################################
diffusion = Diffusion(args, config, rank=0)
diffusion.prepare_model()
diffusion.model.eval()

###############################################################################
# 4) 배치(25장) 한 번에 샘플링 -> 5x5 그리드(여백 없이) 시각화
###############################################################################
device = diffusion.device
num_samples = 16

# (a) 초기 노이즈 (배치 크기 16)
x = np.random.randn(num_samples, config.data.channels, config.data.image_size, config.data.image_size).astype(np.float32)
x = torch.tensor(x, device=device)
classes = torch.randint(0, config.data.num_classes, size=(x.shape[0],)).to(device)
#classes = torch.tensor(classes, device=device)

# (b) 모델로 샘플링 (배치 입력)
sampled_x, classes = diffusion.sample_image(x, diffusion.model, classes=classes, classifier=diffusion.classifier)

# (c) [-1,1] → [0,1] 범위 변환
sampled_x = inverse_data_transform(config, sampled_x)

# (d) 5x5 그리드, padding=0 => 여백 없이
grid = vutils.make_grid(sampled_x, nrow=4, padding=0)

# (e) matplotlib 시각화
grid_np = grid.permute(1, 2, 0).cpu().numpy()
grid_np = np.clip(grid_np, 0, 1)

plt.figure(figsize=(6,6))
plt.imshow(grid_np)
plt.axis('off')
title = f"{args.sample_type}, p={args.dpm_solver_order}, NFE={args.timesteps}, guidance={args.scale}"
plt.title(title, fontweight="bold")
plt.show()

# !mkdir sample/samples
torch.save(sampled_x, 'sample/samples/rbfcpdtargetlgtrapz.pt')
# Out:
# 2025-03-31 14:23:02.574617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743398582.590394   44051 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743398582.595041   44051 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-31 14:23:02.611202: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO - main.py - 2025-03-31 14:23:04,372 - Using device: cuda
# [prepare_model] Model is ready.
# /data/data/rbfsolverglq10laggrid/NFE=20,p=3,dataset=IMAGENET128.npy loaded!
# mkdir: cannot create directory ‘sample/samples’: File exists
